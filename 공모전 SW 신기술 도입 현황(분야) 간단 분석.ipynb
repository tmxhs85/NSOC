# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
font_loc = 'C:/Windows/Fonts/H2PORM.TTF'
font_name = fm.FontProperties(fname=font_loc).get_name()
plt.rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
a = pd.read_csv("C:/Users/user/Downloads/공모전 데이터셋/SW 신기술 도입 현황(분야).csv",encoding='utf-8')

# %%
a
# Out:
#       시점    특성             분야  사물인터넷(스마트센서 포함)  클라우드컴퓨팅  빅데이터  인공지능  블록체인  \
# 0   2020   제조업             통신             51.5     18.5   9.7   1.7   0.1
# 1   2020   제조업           전기전자             56.5     14.1   3.1   2.5   0.2
# 2   2020   제조업            자동차             50.7     11.9   5.4   1.4   0.1
# 3   2020   제조업           의료기기             38.5      4.0   0.1   2.3   0.0
# 4   2020   제조업             조선             58.0     17.1   2.0   0.9   0.0
# 5   2020   제조업          국방/항공             45.8     14.3   6.2   0.6   0.0
# 6   2020   제조업           기계로봇             45.9     11.4   5.9   1.4   0.0
# 7   2020   제조업        철강/석유화학             58.1     17.1   1.5   0.6   0.0
# 8   2020   제조업         에너지/환경             44.7     13.1   0.6   0.1   0.1
# 9   2020   제조업            건설업             29.2     13.5   0.8   0.1   0.0
# 10  2020   제조업           섬유제조             59.0      8.6   1.9   1.7   0.0
# 11  2020  서비스업            금융업             39.3     23.1  28.1   1.1   4.8
# ...

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=a[a['특성']=='제조업']['시점'],y=a[a['특성']=='제조업']['빅데이터'],hue=a[a['특성']=='제조업']['분야'])
# Out:
# <AxesSubplot:xlabel='시점', ylabel='빅데이터'>

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=a[a['특성']=='제조업']['시점'],y=a[a['특성']=='제조업']['인공지능'],hue=a[a['특성']=='제조업']['분야'])
# Out:
# <AxesSubplot:xlabel='시점', ylabel='인공지능'>

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=a[a['특성']=='서비스업']['시점'],y=a[a['특성']=='서비스업']['빅데이터'],hue=a[a['특성']=='서비스업']['분야'])
# Out:
# <AxesSubplot:xlabel='시점', ylabel='빅데이터'>

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=a[a['특성']=='서비스업']['시점'],y=a[a['특성']=='서비스업']['인공지능'],hue=a[a['특성']=='서비스업']['분야'])
# Out:
# <AxesSubplot:xlabel='시점', ylabel='인공지능'>
