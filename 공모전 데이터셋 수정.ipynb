# %%
import pandas as pd

# %%
a = pd.read_csv('SW 신기술 도입 애로사항.csv',encoding='UTF-8')

# %%
a
# Out:
#       시점 특성별(1)        특성별(2)         특성별(3)  내부 운용의 기술력 부족   신기술 도입자금 부족  \
# 0   2019   기업규모            전체             소계            18.6         29.3
# 1   2019   기업규모             소             소계            18.7         29.0
# 2   2019   기업규모             중             소계            16.8         33.0
# 3   2019   기업규모             대             소계            11.1         10.6
# 4   2020     전체            소계             소계            20.4         17.6
# 5   2020    업종별           제조업             소계            14.4         14.2
# 6   2020    업종별           제조업             통신             6.4          3.9
# 7   2020    업종별           제조업           전기전자            29.4         32.5
# 8   2020    업종별           제조업            자동차             2.9          2.4
# 9   2020    업종별           제조업           의료기기             8.9          4.3
# 10  2020    업종별           제조업             조선            54.1         18.9
# 11  2020    업종별           제조업          국방/항공             5.4          5.2
# ...

# %%
a['특성별(2)'][1] = '100명 미만'
# Out:
# d:\anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
a['특성별(2)'][2] = '100~1000명 미만'
a['특성별(2)'][3] = '1000명 이상'
# Out:
# d:\anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# d:\anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
a[a['특성별(1)'] == '업종별']
# Out:
#       시점 특성별(1) 특성별(2)         특성별(3)  내부 운용의 기술력 부족   신기술 도입자금 부족  \
# 5   2020    업종별    제조업             소계            14.4         14.2
# 6   2020    업종별    제조업             통신             6.4          3.9
# 7   2020    업종별    제조업           전기전자            29.4         32.5
# 8   2020    업종별    제조업            자동차             2.9          2.4
# 9   2020    업종별    제조업           의료기기             8.9          4.3
# 10  2020    업종별    제조업             조선            54.1         18.9
# 11  2020    업종별    제조업          국방/항공             5.4          5.2
# 12  2020    업종별    제조업           기계로봇             6.1          6.0
# 13  2020    업종별    제조업        철강/석유화학            27.3         28.1
# 14  2020    업종별    제조업         에너지/환경            13.3          5.3
# 15  2020    업종별    제조업            건설업             0.3          0.2
# 16  2020    업종별    제조업           섬유제조            19.3         27.0
# 17  2020    업종별   서비스업             소계            25.7         20.7
# ...

# %%
a[a['특성별(2)'] == '전체']['특성별(1)'] = '전체'
# Out:
# d:\anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
a['특성별(1)'][0] = '전체'
# Out:
# d:\anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
a['특성별(2)'][0] = '소계'
# Out:
# d:\anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
aa = a[a['특성별(1)']=='전체'].reset_index(drop=True)

# %%
aa
# Out:
#      시점  내부 운용의 기술력 부족   신기술 도입자금 부족  투자대비 성과의 불확실성  적합한 전문 정보 부족  \
# 0  2019            18.6         29.3           24.5           5.3
# 1  2020            20.4         17.6           11.6           5.4
# 2  2021             1.3          1.7           34.2          31.1
#
#    상호보완 및 표준화 미비  경영진의 관심 부족  보안 문제  관련 시장의 미성숙  관련 법/제도로 인한 과도한 규제  \
# 0            3.0         1.7    5.3         0.6                 1.0
# 1            3.2         2.0    2.0         1.6                 0.4
# 2           29.6         0.0    0.0         0.0                 0.0
#
#    국내에 전문외부업체 부족    기타    없음
# 0            0.3   0.0  10.2
# 1            0.2  35.8     -
# 2            0.0   1.5   0.4

# %%
ab = a[a['특성별(1)']=='업종별'].reset_index(drop=True)

# %%
ab.drop(columns='특성별(1)',inplace=True)

# %%
ab['특성'] = ab['특성별(2)']

# %%
ab['분야'] = ab['특성별(3)']

# %%
ab.drop(columns='특성별(2)',inplace=True)
ab.drop(columns='특성별(3)',inplace=True)

# %%
ab.columns
# Out:
# Index(['시점', '내부 운용의 기술력 부족 ', '신기술 도입자금 부족', '투자대비 성과의 불확실성', '적합한 전문 정보 부족',
#        '상호보완 및 표준화 미비', '경영진의 관심 부족', '보안 문제', '관련 시장의 미성숙',
#        '관련 법/제도로 인한 과도한 규제', '국내에 전문외부업체 부족', '기타', '없음', '특성', '분야'],
#       dtype='object')

# %%
ab.columns = ['시점', '내부 운용의 기술력 부족 ', '신기술 도입자금 부족', '투자대비 성과의 불확실성', '적합한 전문 정보 부족',
       '상호보완 및 표준화 미비', '경영진의 관심 부족', '보안 문제', '관련 시장의 미성숙',
       '관련 법/제도로 인한 과도한 규제', '국내에 전문외부업체 부족', '기타', '없음', '특성', '분야']

# %%
ab = ab[['특성','분야','시점','내부 운용의 기술력 부족 ','신기술 도입자금 부족','투자대비 성과의 불확실성','적합한 전문 정보 부족','상호보완 및 표준화 미비','경영진의 관심 부족','보안 문제','관련 시장의 미성숙','관련 법/제도로 인한 과도한 규제','국내에 전문외부업체 부족','기타','없음']]

# %%
ab
# Out:
#       특성             분야    시점  내부 운용의 기술력 부족   신기술 도입자금 부족  투자대비 성과의 불확실성  \
# 0    제조업             소계  2020            14.4         14.2            7.5
# 1    제조업             통신  2020             6.4          3.9            5.1
# 2    제조업           전기전자  2020            29.4         32.5           11.1
# 3    제조업            자동차  2020             2.9          2.4            3.0
# 4    제조업           의료기기  2020             8.9          4.3            0.5
# 5    제조업             조선  2020            54.1         18.9           21.0
# 6    제조업          국방/항공  2020             5.4          5.2            8.0
# 7    제조업           기계로봇  2020             6.1          6.0            8.5
# 8    제조업        철강/석유화학  2020            27.3         28.1            9.8
# 9    제조업         에너지/환경  2020            13.3          5.3           13.8
# 10   제조업            건설업  2020             0.3          0.2            0.1
# 11   제조업           섬유제조  2020            19.3         27.0           10.1
# ...

# %%
ac = a[a['특성별(1)']=='기업규모'].reset_index(drop=True)

# %%
ac
# Out:
#      시점 특성별(1)        특성별(2) 특성별(3)  내부 운용의 기술력 부족   신기술 도입자금 부족  \
# 0  2019   기업규모       100명 미만     소계            18.7         29.0
# 1  2019   기업규모  100~1000명 미만     소계            16.8         33.0
# 2  2019   기업규모      1000명 이상     소계            11.1         10.6
# 3  2020   기업규모       100명 미만     소계            19.5         17.6
# 4  2020   기업규모  100~1000명 미만     소계            33.0         17.3
# 5  2020   기업규모      1000명 이상     소계            17.8         30.9
# 6  2021   기업규모       100명 미만     소계             1.0          1.3
# 7  2021   기업규모  100~1000명 미만     소계            29.7         30.0
# 8  2021   기업규모      1000명 이상     소계            11.1         12.0
#
#    투자대비 성과의 불확실성  적합한 전문 정보 부족  상호보완 및 표준화 미비  경영진의 관심 부족  보안 문제  관련 시장의 미성숙  \
# 0           24.6           5.3            3.0         1.7    5.2         0.7
# 1           23.3           4.4            3.6         1.5    7.3         0.2
# 2           36.5           8.9            8.6         0.0    5.0         5.2
# ...

# %%
ac.drop(columns='특성별(1)',inplace=True)
ac.drop(columns='특성별(3)',inplace=True)

# %%
ac.rename(columns={'특성별(2)':'기업규모'},inplace=True)

# %%
ac
# Out:
#      시점          기업규모  내부 운용의 기술력 부족   신기술 도입자금 부족  투자대비 성과의 불확실성  \
# 0  2019       100명 미만            18.7         29.0           24.6
# 1  2019  100~1000명 미만            16.8         33.0           23.3
# 2  2019      1000명 이상            11.1         10.6           36.5
# 3  2020       100명 미만            19.5         17.6           11.7
# 4  2020  100~1000명 미만            33.0         17.3            9.4
# 5  2020      1000명 이상            17.8         30.9           29.2
# 6  2021       100명 미만             1.0          1.3           34.4
# 7  2021  100~1000명 미만            29.7         30.0           12.8
# 8  2021      1000명 이상            11.1         12.0           46.1
#
#    적합한 전문 정보 부족  상호보완 및 표준화 미비  경영진의 관심 부족  보안 문제  관련 시장의 미성숙  \
# 0           5.3            3.0         1.7    5.2         0.7
# 1           4.4            3.6         1.5    7.3         0.2
# 2           8.9            8.6         0.0    5.0         5.2
# ...

# %%
aa.to_csv('SW 신기술 도입 애로사항(전체).csv',encoding='UTF-8',index=False)
ab.to_csv('SW 신기술 도입 애로사항(분야).csv',encoding='UTF-8',index=False)
ac.to_csv('SW 신기술 도입 애로사항(기업규모).csv',encoding='UTF-8',index=False)

# %%
b = pd.read_csv('SW 신기술 도입 현황.csv',encoding='UTF-8')

# %%
ba = b[b['특성별(1)']=='업종별']

# %%
baa = ba[ba['특성별(3)']=='소계'].reset_index(drop=True)

# %%
baa
# Out:
#      시점 특성별(1) 특성별(2) 특성별(3)  사물인터넷(스마트센서 포함)  클라우드컴퓨팅  빅데이터  인공지능  블록체인  \
# 0  2019    업종별     전체     소계            50.38    14.18  4.21  0.77  0.30
# 1  2019    업종별    제조업     소계            46.95     9.39  1.87  1.35  0.15
# 2  2019    업종별   서비스업     소계            52.73    17.46  5.82  0.37  0.41
# 3  2020    업종별    제조업     소계            48.20    13.00  3.00  1.20  0.10
# 4  2020    업종별   서비스업     소계            56.00    15.30  6.10  0.60  0.50
# 5  2021    업종별    제조업     소계            50.90    14.30  4.80  1.70  0.10
# 6  2021    업종별   서비스업     소계            60.00    18.20  6.80  2.10  0.70
#
#    실감형 SW(AR/VR/MR)     없음
# 0              0.28  38.98
# 1              0.37  46.15
# 2              0.23  34.06
# 3              0.40  47.00
# 4              0.10  40.50
# 5              1.40  41.60
# 6              0.30  31.00

# %%
baa = baa.reset_index(drop=True)

# %%
baa = baa.drop(columns='특성별(3)')

# %%
baa = baa.drop(columns='특성별(1)')

# %%
baa.rename(columns={'특성별(2)':'업종별'},inplace=True)

# %%
baa
# Out:
#      시점   업종별  사물인터넷(스마트센서 포함)  클라우드컴퓨팅  빅데이터  인공지능  블록체인  실감형 SW(AR/VR/MR)  \
# 0  2019   제조업            46.95     9.39  1.87  1.35  0.15              0.37
# 1  2019  서비스업            52.73    17.46  5.82  0.37  0.41              0.23
# 2  2020   제조업            48.20    13.00  3.00  1.20  0.10              0.40
# 3  2020  서비스업            56.00    15.30  6.10  0.60  0.50              0.10
# 4  2021   제조업            50.90    14.30  4.80  1.70  0.10              1.40
# 5  2021  서비스업            60.00    18.20  6.80  2.10  0.70              0.30
#
#       없음
# 0  46.15
# 1  34.06
# 2  47.00
# 3  40.50
# 4  41.60
# 5  31.00

# %%
b['특성별(2)'][0] = '소계'
# Out:
# d:\anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
bb = b[b['특성별(2)']=='소계'].reset_index(drop=True)

# %%
bb
# Out:
#      시점 특성별(1) 특성별(2) 특성별(3)  사물인터넷(스마트센서 포함)  클라우드컴퓨팅  빅데이터  인공지능  블록체인  \
# 0  2019    업종별     소계     소계            50.38    14.18  4.21  0.77   0.3
# 1  2020     전체     소계     소계            52.30    14.20  4.70  0.90   0.3
# 2  2021     전체     소계     소계            55.70    16.30  5.90  1.90   0.4
#
#    실감형 SW(AR/VR/MR)     없음
# 0              0.28  38.98
# 1              0.20  43.60
# 2              0.80  36.00

# %%
bb.drop(columns=['특성별(1)','특성별(2)','특성별(3)'],inplace=True)

# %%
bb
# Out:
#      시점  사물인터넷(스마트센서 포함)  클라우드컴퓨팅  빅데이터  인공지능  블록체인  실감형 SW(AR/VR/MR)     없음
# 0  2019            50.38    14.18  4.21  0.77   0.3              0.28  38.98
# 1  2020            52.30    14.20  4.70  0.90   0.3              0.20  43.60
# 2  2021            55.70    16.30  5.90  1.90   0.4              0.80  36.00

# %%
bc = b[b['특성별(3)']!='소계'].reset_index(drop=True)

# %%
bc.drop(columns='특성별(1)',inplace=True)

# %%
bc.rename(columns={'특성별(2)':'특성','특성별(3)':'분야'},inplace=True)

# %%
bc
# Out:
#       시점    특성             분야  사물인터넷(스마트센서 포함)  클라우드컴퓨팅  빅데이터  인공지능  블록체인  \
# 0   2020   제조업             통신             51.5     18.5   9.7   1.7   0.1
# 1   2020   제조업           전기전자             56.5     14.1   3.1   2.5   0.2
# 2   2020   제조업            자동차             50.7     11.9   5.4   1.4   0.1
# 3   2020   제조업           의료기기             38.5      4.0   0.1   2.3   0.0
# 4   2020   제조업             조선             58.0     17.1   2.0   0.9   0.0
# 5   2020   제조업          국방/항공             45.8     14.3   6.2   0.6   0.0
# 6   2020   제조업           기계로봇             45.9     11.4   5.9   1.4   0.0
# 7   2020   제조업        철강/석유화학             58.1     17.1   1.5   0.6   0.0
# 8   2020   제조업         에너지/환경             44.7     13.1   0.6   0.1   0.1
# 9   2020   제조업            건설업             29.2     13.5   0.8   0.1   0.0
# 10  2020   제조업           섬유제조             59.0      8.6   1.9   1.7   0.0
# 11  2020  서비스업            금융업             39.3     23.1  28.1   1.1   4.8
# ...

# %%
baa.to_csv('SW 신기술 도입 현황(업종).csv',encoding='UTF-8',index=False)
bb.to_csv('SW 신기술 도입 현황(전체).csv',encoding='UTF-8',index=False)
bc.to_csv('SW 신기술 도입 현황(분야).csv',encoding='UTF-8',index=False)

# %%
c = pd.read_csv('SW 신기술 분야 인력 현황.csv',encoding='UTF-8')

# %%
c
# Out:
#      시점 산업대분류별(1)  빅데이터  클라우드 서비스  인공지능  사물인터넷  실감형SW(AR/VR/MR)  블록체인  \
# 0  2019        전체  29.6      19.8   6.4   40.2              0.7   0.8
# 1  2019       제조업  14.0      13.4  13.6   53.9              1.1   0.4
# 2  2019      서비스업  40.4      24.1   1.5   30.8              0.3   1.1
# 3  2020        전체  29.2      19.6   7.3   40.3              0.7   0.9
# 4  2020       제조업  22.4      17.9  12.9   42.1              1.0   0.7
# 5  2020      서비스업  34.2      20.8   3.1   39.1              0.4   1.1
# 6  2021        전체  26.2      22.1   8.1   40.4              0.9   0.6
# 7  2021       제조업  20.7      20.6  11.1   43.4              1.6   0.4
# 8  2021      서비스업  30.2      23.2   6.0   38.2              0.4   0.8
#
#    기타(로봇설계 등)
# 0         2.5
# 1         3.5
# 2         1.8
# 3         2.0
# 4         3.1
# 5         1.3
# 6         1.6
# 7         2.2
# 8         1.1

# %%
ca = c[c['산업대분류별(1)']=='전체'].reset_index(drop=True)

# %%
ca.drop(columns='산업대분류별(1)',inplace=True)

# %%
ca
# Out:
#      시점  빅데이터  클라우드 서비스  인공지능  사물인터넷  실감형SW(AR/VR/MR)  블록체인  기타(로봇설계 등)
# 0  2019  29.6      19.8   6.4   40.2              0.7   0.8         2.5
# 1  2020  29.2      19.6   7.3   40.3              0.7   0.9         2.0
# 2  2021  26.2      22.1   8.1   40.4              0.9   0.6         1.6

# %%
cb = c[c['산업대분류별(1)']!='전체'].reset_index(drop=True)

# %%
cb.rename(columns={'산업대분류별(1)':'분야'},inplace=True)

# %%
cb
# Out:
#      시점    분야  빅데이터  클라우드 서비스  인공지능  사물인터넷  실감형SW(AR/VR/MR)  블록체인  기타(로봇설계 등)
# 0  2019   제조업  14.0      13.4  13.6   53.9              1.1   0.4         3.5
# 1  2019  서비스업  40.4      24.1   1.5   30.8              0.3   1.1         1.8
# 2  2020   제조업  22.4      17.9  12.9   42.1              1.0   0.7         3.1
# 3  2020  서비스업  34.2      20.8   3.1   39.1              0.4   1.1         1.3
# 4  2021   제조업  20.7      20.6  11.1   43.4              1.6   0.4         2.2
# 5  2021  서비스업  30.2      23.2   6.0   38.2              0.4   0.8         1.1

# %%
ca.to_csv('SW 신기술 분야 인력 현황(전체).csv',encoding='UTF-8',index=False)
cb.to_csv('SW 신기술 분야 인력 현황(분야).csv',encoding='UTF-8',index=False)
